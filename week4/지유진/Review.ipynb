# %% [markdown]
# # 기계학습 입문 : Review 1(Diabetes)
#
# 앞서 진행했던 입문 문제들을 복습하는 차원에서 다음 문제들을 풀어 Github에 업로드하여 주세요.</br>
# **주의** : 언급하는 결과만을 구현하면 되며, 정해진 정답은 없습니다.

# %% [markdown]
# ## 1. 데이터 분석
# ### 1-1. 데이터 읽어오기
#
# 훈련데이터 `train.csv`파일, 시험 데이터 `test.csv`파일, 제출 파일 `sample_submission.csv`파일을 각각 불러와 적절한 변수에 할당시켜 주세요.
# * 이때 불러와서 변수에 할당되는 객체가 무엇인지 코드 셀 아래에 적어주세요.

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample = pd.read_csv('sample_submission.csv')

# %% [markdown]
# ### 1-2. 데이터 확인
# * 훈련 데이터의 상위 혹은 하위 5개의 행(row)을 확인해보세요.
# * 확인해 보았다면, 각 열(column)이 무엇을 의미하는 지 적어보세요.

# %% [markdown]
# #### 데이터 확인
# * Pregnancies : 임신횟수
# * Glucose : 포도당 농도
# * BloodPressure : 혈압
# * SkinThickness : 피부두께
# * Insulin : 인슐린
# * BMI : 체질량지수
# * DiabetesPedigreeFunction: 당뇨병 혈통 기능
# * Age : 나이
# * Outcome : 당뇨병 여부(target)

# %%
train.head()
# Out:
#           ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0  TRAIN_000            4      103             60             33      192
# 1  TRAIN_001           10      133             68              0        0
# 2  TRAIN_002            4      112             78             40        0
# 3  TRAIN_003            1      119             88             41      170
# 4  TRAIN_004            1      114             66             36      200
#
#     BMI  DiabetesPedigreeFunction  Age  Outcome
# 0  24.0                     0.966   33        0
# 1  27.0                     0.245   36        0
# 2  39.4                     0.236   38        0
# 3  45.3                     0.507   26        0
# 4  38.1                     0.289   21        0

# %%
train.tail()
# Out:
#             ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 647  TRAIN_647            1       91             64             24        0
# 648  TRAIN_648           10      122             68              0        0
# 649  TRAIN_649            8       84             74             31        0
# 650  TRAIN_650            2       81             72             15       76
# 651  TRAIN_651            1      107             68             19        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 647  29.2                     0.192   21        0
# 648  31.2                     0.258   41        0
# 649  38.3                     0.457   39        0
# 650  30.1                     0.547   25        0
# 651  26.5                     0.165   24        0

# %% [markdown]
# ## 1-3. 간단한 정보 및 통계치(기술통계량) 확인
# 1. 훈련 데이터와 시험 데이터의 결측치 및 자료형을 간단하게 확인해주세요. 결과에 대한 분석을 간단하게 적어주세요.
# 2. 훈련 데이터와 시험 데이터의 간단한 통계치를 확인하고, 결과에 대한 본인의 생각을 적어주세요.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        652 non-null    object
#  1   Pregnancies               652 non-null    int64
#  2   Glucose                   652 non-null    int64
#  3   BloodPressure             652 non-null    int64
#  4   SkinThickness             652 non-null    int64
#  5   Insulin                   652 non-null    int64
#  6   BMI                       652 non-null    float64
#  7   DiabetesPedigreeFunction  652 non-null    float64
#  8   Age                       652 non-null    int64
#  9   Outcome                   652 non-null    int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 51.1+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        116 non-null    object
#  1   Pregnancies               116 non-null    int64
#  2   Glucose                   116 non-null    int64
#  3   BloodPressure             116 non-null    int64
#  4   SkinThickness             116 non-null    int64
#  5   Insulin                   116 non-null    int64
#  6   BMI                       116 non-null    float64
#  7   DiabetesPedigreeFunction  116 non-null    float64
#  8   Age                       116 non-null    int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 8.3+ KB

# %% [markdown]
# ## 2. 데이터 전처리
# ### 2-1. 행과 열 데이터 읽어와보기.(인덱싱과 슬라이싱)
# * 훈련 데이터의 10번째부터 29번째까지 행(row) 데이터 읽어봐주세요.

# %%
train.iloc[9:29]
# Out:
#            ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 9   TRAIN_009            1      167             74             17      144
# 10  TRAIN_010            4      145             82             18        0
# 11  TRAIN_011            8      124             76             24      600
# 12  TRAIN_012            4      184             78             39      277
# 13  TRAIN_013            6      134             70             23      130
# 14  TRAIN_014            9      134             74             33       60
# 15  TRAIN_015            5      103            108             37        0
# 16  TRAIN_016            0      113             76              0        0
# 17  TRAIN_017            2      155             74             17       96
# 18  TRAIN_018            5       77             82             41       42
# 19  TRAIN_019            4       95             64              0        0
# 20  TRAIN_020            2      112             75             32        0
# 21  TRAIN_021           10       94             72             18        0
# 22  TRAIN_022            6      154             78             41      140
# 23  TRAIN_023            4       92             80              0        0
# 24  TRAIN_024            1      117             60             23      106
# 25  TRAIN_025            1      149             68             29      127
# 26  TRAIN_026            7      105              0              0        0
# 27  TRAIN_027            5      111             72             28        0
# 28  TRAIN_028            6      147             80              0        0
#
#      BMI  DiabetesPedigreeFunction  Age  Outcome
# 9   23.4                     0.447   33        1
# 10  32.5                     0.235   70        1
# 11  28.7                     0.687   52        1
# 12  37.0                     0.264   31        1
# 13  35.4                     0.542   29        1
# 14  25.9                     0.460   81        0
# 15  39.2                     0.305   65        0
# 16  33.3                     0.278   23        1
# 17  26.6                     0.433   27        1
# 18  35.8                     0.156   35        0
# 19  32.0                     0.161   31        1
# 20  35.7                     0.148   21        0
# 21  23.1                     0.595   56        0
# 22  46.1                     0.571   27        0
# 23  42.2                     0.237   29        0
# 24  33.8                     0.466   27        0
# 25  29.3                     0.349   42        1
# 26   0.0                     0.305   24        0
# 27  23.9                     0.407   27        0
# 28  29.5                     0.178   50        1

# %% [markdown]
# 1. 훈련 데이터의 78번째부터 128번째까지 행(row) 데이터
# 2. 1번에서 가져온 데이터의 `SkinThickness`와 `Insulin` 열(column) 데이터

# %%
train.iloc[77:128][['SkinThickness', 'Insulin']]
# Out:
#      SkinThickness  Insulin
# 77               0        0
# 78              35        0
# 79              20        0
# 80              32      274
# 81              18       76
# 82              22        0
# 83              50      204
# 84               0        0
# 85              25      184
# 86              23      115
# 87              23      170
# 88              36        0
# 89              21      158
# 90              33      215
# 91               0        0
# 92               0        0
# 93               0        0
# 94              29      126
# 95               0        0
# 96              37      182
# 97               0        0
# 98              29      325
# 99              28        0
# 100             26        0
# 101             46      180
# 102              0        0
# 103             23       76
# 104              7      258
# 105              0        0
# 106             26       71
# 107             34      300
# 108             37      120
# 109              0        0
# 110             18       76
# 111              0        0
# 112             14      148
# 113             15        0
# 114             37      140
# 115             17      265
# 116             36      245
# 117             27      540
# 118             32        0
# 119             33      146
# 120             32       88
# 121              0        0
# 122             19       25
# 123             18       40
# 124             46      231
# 125              0        0
# 126             40       94
# 127             10       85

# %% [markdown]
# * 훈련 데이터의 100번째부터 200번째까지 행, 'BMI'열의 데이터를 2개씩 건너뛰며 역순으로 출력

# %%
train.iloc[199:98:-2][['BMI']]

# 아래 코드도 같은 행위
# train.iloc[99:200:2][['BMI']].sort_index(ascending=False)
# Out:
#       BMI
# 199  30.1
# 197  42.9
# 195  40.9
# 193  23.7
# 191  35.5
# 189  30.0
# 187  32.4
# 185  43.5
# 183  38.8
# 181  29.7
# 179  29.7
# 177  24.0
# 175  35.9
# 173  33.2
# 171  21.8
# 169  43.3
# 167  37.3
# 165  38.7
# 163  42.9
# 161  42.3
# 159  25.2
# 157  30.1
# 155  46.8
# 153  27.4
# 151   0.0
# 149  34.5
# 147  37.4
# 145  29.7
# 143  22.9
# 141  26.4
# 139  39.9
# 137  29.8
# 135   0.0
# 133  19.4
# 131  34.8
# 129  25.9
# 127  29.5
# 125  31.2
# 123  26.6
# 121  26.1
# 119  36.6
# 117  38.7
# 115  24.2
# 113  30.0
# 111  31.2
# 109  35.0
# 107  33.7
# 105  24.2
# 103  30.4
# 101  46.1
# 99   32.5

# %% [markdown]
# - 훈련 데이터에서 Glucose 열의 값이 10 이상이며, 'Glucose' 열의 값이 160 미만인 행

# %%
train[(train['Glucose'] >= 10) & (train['Glucose'] < 160)]
# Out:
#             ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0    TRAIN_000            4      103             60             33      192
# 1    TRAIN_001           10      133             68              0        0
# 2    TRAIN_002            4      112             78             40        0
# 3    TRAIN_003            1      119             88             41      170
# 4    TRAIN_004            1      114             66             36      200
# ..         ...          ...      ...            ...            ...      ...
# 647  TRAIN_647            1       91             64             24        0
# 648  TRAIN_648           10      122             68              0        0
# 649  TRAIN_649            8       84             74             31        0
# 650  TRAIN_650            2       81             72             15       76
# 651  TRAIN_651            1      107             68             19        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    24.0                     0.966   33        0
# 1    27.0                     0.245   36        0
# 2    39.4                     0.236   38        0
# 3    45.3                     0.507   26        0
# 4    38.1                     0.289   21        0
# ..    ...                       ...  ...      ...
# 647  29.2                     0.192   21        0
# 648  31.2                     0.258   41        0
# 649  38.3                     0.457   39        0
# 650  30.1                     0.547   25        0
# 651  26.5                     0.165   24        0
#
# [563 rows x 10 columns]

# %% [markdown]
# * 훈련 데이터에서 `Insulin` 열의 값이 0인 행, `Insulin`열을 제외하고 모든 열 출력

# %%
zero_insulin = train[train['Insulin'] == 0]
zero_insulin.loc[:, zero_insulin.columns != 'Insulin']
# Out:
#             ID  Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 1    TRAIN_001           10      133             68              0  27.0
# 2    TRAIN_002            4      112             78             40  39.4
# 8    TRAIN_008            1      124             60             32  35.8
# 10   TRAIN_010            4      145             82             18  32.5
# 15   TRAIN_015            5      103            108             37  39.2
# ..         ...          ...      ...            ...            ...   ...
# 646  TRAIN_646            6      166             74              0  26.6
# 647  TRAIN_647            1       91             64             24  29.2
# 648  TRAIN_648           10      122             68              0  31.2
# 649  TRAIN_649            8       84             74             31  38.3
# 651  TRAIN_651            1      107             68             19  26.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.245   36        0
# 2                       0.236   38        0
# 8                       0.514   21        0
# 10                      0.235   70        1
# 15                      0.305   65        0
# ..                        ...  ...      ...
# 646                     0.304   66        0
# 647                     0.192   21        0
# 648                     0.258   41        0
# 649                     0.457   39        0
# 651                     0.165   24        0
#
# [318 rows x 9 columns]

# %% [markdown]
# * 훈련 데이터에서 `BMI`열의 값이 20이하 혹은 40이상인 행의 `BloodPressure`와 `Insulin`열 출력

# %%
train[(train['BMI'] <= 20) | (train['BMI'] >= 40)][['BloodPressure', 'Insulin']]
# Out:
#      BloodPressure  Insulin
# 3               88      170
# 22              78      140
# 23              80        0
# 26               0        0
# 32              70      271
# ..             ...      ...
# 631             78       48
# 635             88      510
# 636            110      240
# 638             62      480
# 640             92        0
#
# [99 rows x 2 columns]

# %% [markdown]
# ### 2-2. 열 삭제
# * 학습에 영향을 미치지 못하는 것으로 **판단되는** `ID` 열 삭제

# %%
train = train.drop('ID', axis=1)
train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              4      103             60             33      192  24.0
# 1             10      133             68              0        0  27.0
# 2              4      112             78             40        0  39.4
# 3              1      119             88             41      170  45.3
# 4              1      114             66             36      200  38.1
# ..           ...      ...            ...            ...      ...   ...
# 647            1       91             64             24        0  29.2
# 648           10      122             68              0        0  31.2
# 649            8       84             74             31        0  38.3
# 650            2       81             72             15       76  30.1
# 651            1      107             68             19        0  26.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.966   33        0
# 1                       0.245   36        0
# 2                       0.236   38        0
# 3                       0.507   26        0
# 4                       0.289   21        0
# ..                        ...  ...      ...
# 647                     0.192   21        0
# 648                     0.258   41        0
# 649                     0.457   39        0
# 650                     0.547   25        0
# 651                     0.165   24        0
#
# [652 rows x 9 columns]

# %%
test = test.drop('ID', axis=1)
test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5      112             66              0        0  37.8
# 1              3      107             62             13       48  22.9
# 2              3      113             44             13        0  22.4
# 3              6      190             92              0        0  35.5
# 4              1      107             72             30       82  30.8
# ..           ...      ...            ...            ...      ...   ...
# 111           10      111             70             27        0  27.5
# 112            1      119             54             13       50  22.3
# 113            3      187             70             22      200  36.4
# 114            3      100             68             23       81  31.6
# 115            2       84              0              0        0   0.0
#
#      DiabetesPedigreeFunction  Age
# 0                       0.261   41
# 1                       0.678   23
# 2                       0.140   22
# 3                       0.278   66
# 4                       0.821   24
# ..                        ...  ...
# 111                     0.141   40
# 112                     0.205   24
# 113                     0.408   36
# 114                     0.949   28
# 115                     0.304   21
#
# [116 rows x 8 columns]

# %% [markdown]
# ### 2-3 연속형 데이터의 범주화(BloodPressure)
# * `BloodPressure`의 열(column) 값을 4개 구간으로 분류
#     - 0~20 : A
#     - 21~30 : B
#     - 31~40 : C
#     - 41~60 : D
# * 분류된 값들을 `bloodpressure_cut`이라는 열을 생성하여 값을 할당

# %%
def bloodpressure_cut(x):
  result = ''
  if 0 <= x <= 20:
    result = 'A'
  elif x <= 30:
    result = 'B'
  elif x <= 40:
    result = 'C'
  else:
    result = 'D'
  return result

# %%
train['bloodpressure_cut'] = train['BloodPressure'].map(bloodpressure_cut)

# %%
train['bloodpressure_cut'].value_counts()
# Out:
# D    617
# A     30
# B      3
# C      2
# Name: bloodpressure_cut, dtype: int64

# %%
test['bloodpressure_cut'] = test['BloodPressure'].map(bloodpressure_cut)

# %% [markdown]
# ### 2-4. 연속형 데이터의 범주화2(Glucose)
# * `Glucose` 피처에 분위수 기준으로 4가지로 분류하기
# * ['normal', 'suspected1', 'suspected2', 'danger']

# %%
train[['Glucose']].describe()
# Out:
#           Glucose
# count  652.000000
# mean   120.946319
# std     31.992394
# min      0.000000
# 25%     99.000000
# 50%    117.000000
# 75%    142.000000
# max    199.000000

# %%
def glucose_cut(x):
  result = ''
  if 0 <= x <= 99:
    result = 'normal'
  elif x <= 117:
    result = 'suspected1'
  elif x <= 142:
    result = 'suspected2'
  else:
    result = 'danger'
  return result

# %%
train['glucose_cut'] = train['Glucose'].map(glucose_cut)

# %%
train['glucose_cut'].value_counts()
# Out:
# normal        171
# suspected2    164
# danger        160
# suspected1    157
# Name: glucose_cut, dtype: int64

# %%
test['glucose_cut'] = test['Glucose'].map(glucose_cut)
# train 데이터의 분위수에 따라 분류

# %%
test['glucose_cut'].value_counts()
# Out:
# suspected1    37
# suspected2    31
# normal        26
# danger        22
# Name: glucose_cut, dtype: int64

# %%
train['glucose_cut']
# Out:
# 0      suspected1
# 1      suspected2
# 2      suspected1
# 3      suspected2
# 4      suspected1
#           ...
# 647        normal
# 648    suspected2
# 649        normal
# 650        normal
# 651    suspected1
# Name: glucose_cut, Length: 652, dtype: object

# %% [markdown]
# ### 2-5. 표준화 및 인코딩
# * 수치형 데이터 : 표준화
# * 범주형 데이터 : 레이블인코딩

# %%
x_train = train.drop(['Outcome'], axis = 1)
y_train = train['Outcome']
x_test = test
# ID column은 위에서 삭제했음

# %%
x_train.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            4      103             60             33      192  24.0
# 1           10      133             68              0        0  27.0
# 2            4      112             78             40        0  39.4
# 3            1      119             88             41      170  45.3
# 4            1      114             66             36      200  38.1
#
#    DiabetesPedigreeFunction  Age bloodpressure_cut glucose_cut
# 0                     0.966   33                 D  suspected1
# 1                     0.245   36                 D  suspected2
# 2                     0.236   38                 D  suspected1
# 3                     0.507   26                 D  suspected2
# 4                     0.289   21                 D  suspected1

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x_train.loc[:,'Pregnancies':'Age'])
# Out:
# StandardScaler()

# %%
scaled_train = scaler.transform(x_train.loc[:,'Pregnancies':'Age'])
scaled_test = scaler.transform(x_test.loc[:,'Pregnancies':'Age'])

sequential_features = scaler.feature_names_in_

for index, feature in enumerate(sequential_features):
    x_train[feature] = scaled_train[:,index]
    x_test[feature] = scaled_test[:,index]

# %%
x_train.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.023064 -0.561386      -0.464064       0.789608  0.944442 -1.066013
# 1     1.827588  0.377056      -0.046726      -1.285030 -0.687406 -0.663612
# 2     0.023064 -0.279854       0.474946       1.229683 -0.687406  0.999645
# 3    -0.879198 -0.060884       0.996618       1.292551  0.757460  1.791034
# 4    -0.879198 -0.217291      -0.151061       0.978212  1.012436  0.825272
#
#    DiabetesPedigreeFunction       Age bloodpressure_cut glucose_cut
# 0                  1.521265 -0.043225                 D  suspected1
# 1                 -0.668604  0.210673                 D  suspected2
# 2                 -0.695939  0.379939                 D  suspected1
# 3                  0.127160 -0.635655                 D  suspected2
# 4                 -0.534964 -1.058819                 D  suspected1

# %%
y_train
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 647    0
# 648    0
# 649    0
# 650    0
# 651    0
# Name: Outcome, Length: 652, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
categorical_data = ['glucose_cut', 'bloodpressure_cut']

for feature in categorical_data:
  le = le.fit(x_train[feature])
  x_train[feature] = le.transform(x_train[feature])

  for label in x_test[feature]:
    if label not in le.classes_:
      le.classes_ = np.append(le.classes_, label)

  x_test[feature] = le.transform(x_test[feature])

# %%
x_train.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.023064 -0.561386      -0.464064       0.789608  0.944442 -1.066013
# 1     1.827588  0.377056      -0.046726      -1.285030 -0.687406 -0.663612
# 2     0.023064 -0.279854       0.474946       1.229683 -0.687406  0.999645
# 3    -0.879198 -0.060884       0.996618       1.292551  0.757460  1.791034
# 4    -0.879198 -0.217291      -0.151061       0.978212  1.012436  0.825272
#
#    DiabetesPedigreeFunction       Age  bloodpressure_cut  glucose_cut
# 0                  1.521265 -0.043225                  3            2
# 1                 -0.668604  0.210673                  3            3
# 2                 -0.695939  0.379939                  3            2
# 3                  0.127160 -0.635655                  3            3
# 4                 -0.534964 -1.058819                  3            2

# %% [markdown]
# ## 3. 모델링

# %%
print(x_train.shape, y_train.shape, x_test.shape)
# Out:
# (652, 10) (652,) (116, 10)

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense

# %%
model = Sequential()  # 현재 model에는 레이어가 하나도 추가되어 있지 않음
model.add(Dense(32, input_shape=(10,), activation='tanh'))
model.add(Dense(1, activation='sigmoid'))

# %%
# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                352
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 385 (1.50 KB)
# Trainable params: 385 (1.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델 훈련
model.fit(x_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 21/21 [==============================] - 2s 4ms/step - loss: 0.7410 - accuracy: 0.4632
# Epoch 2/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6128 - accuracy: 0.6902
# Epoch 3/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5643 - accuracy: 0.7209
# Epoch 4/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5349 - accuracy: 0.7423
# Epoch 5/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5172 - accuracy: 0.7500
# Epoch 6/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5029 - accuracy: 0.7531
# Epoch 7/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4945 - accuracy: 0.7531
# Epoch 8/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4860 - accuracy: 0.7653
# Epoch 9/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4812 - accuracy: 0.7699
# Epoch 10/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4765 - accuracy: 0.7669
# Epoch 11/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4733 - accuracy: 0.7669
# Epoch 12/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4706 - accuracy: 0.7699
# Epoch 13/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4685 - accuracy: 0.7730
# Epoch 14/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4663 - accuracy: 0.7761
# Epoch 15/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4650 - accuracy: 0.7807
# Epoch 16/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4638 - accuracy: 0.7807
# Epoch 17/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4631 - accuracy: 0.7837
# Epoch 18/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4617 - accuracy: 0.7837
# Epoch 19/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4610 - accuracy: 0.7929
# Epoch 20/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4601 - accuracy: 0.7837
# Epoch 21/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4593 - accuracy: 0.7899
# Epoch 22/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4584 - accuracy: 0.7883
# Epoch 23/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4582 - accuracy: 0.7883
# Epoch 24/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4572 - accuracy: 0.7868
# Epoch 25/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4563 - accuracy: 0.7868
# Epoch 26/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4562 - accuracy: 0.7883
# Epoch 27/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4549 - accuracy: 0.7868
# Epoch 28/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4547 - accuracy: 0.7914
# Epoch 29/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4534 - accuracy: 0.7929
# Epoch 30/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4526 - accuracy: 0.7945
# Epoch 31/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4519 - accuracy: 0.7914
# Epoch 32/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4517 - accuracy: 0.7883
# Epoch 33/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4511 - accuracy: 0.7914
# Epoch 34/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4508 - accuracy: 0.7945
# Epoch 35/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4498 - accuracy: 0.7914
# Epoch 36/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4498 - accuracy: 0.7868
# Epoch 37/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4487 - accuracy: 0.7945
# Epoch 38/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4481 - accuracy: 0.7991
# Epoch 39/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4482 - accuracy: 0.7899
# Epoch 40/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4469 - accuracy: 0.7945
# Epoch 41/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4458 - accuracy: 0.8006
# Epoch 42/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4454 - accuracy: 0.7868
# Epoch 43/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4450 - accuracy: 0.7899
# Epoch 44/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4441 - accuracy: 0.7914
# Epoch 45/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4439 - accuracy: 0.7914
# Epoch 46/50
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4437 - accuracy: 0.7914
# Epoch 47/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4423 - accuracy: 0.7960
# Epoch 48/50
# 21/21 [==============================] - 0s 4ms/step - loss: 0.4421 - accuracy: 0.7945
# Epoch 49/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4414 - accuracy: 0.7975
# Epoch 50/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4402 - accuracy: 0.7945

# %%
# 모델 예측
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
y_pred[0]
# Out:
# array([0.4137867], dtype=float32)

# %%
# 예측값 이진화 (0 또는 1로 변환)
y_pred = (y_pred > 0.5).astype(int)

# %%
sample['Outcome'] = y_pred
sample.to_csv('submission.csv', index = False)
